# %%
# !pip install --no-dependencies --quiet streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 64.8 MB/s eta 0:00:00:00:01:01

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2025-06-29 16:06:23--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 75.2.60.68, 13.248.244.96, 35.71.179.82, ...
# Connecting to bin.equinox.io (bin.equinox.io)|75.2.60.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  15.0MB/s    in 0.9s
#
# 2025-06-29 16:06:25 (15.0 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]

# %%
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !pip install --quiet pyngrok
# !pip install --no-dependencies --quiet protobuf==3.20.*
# !pip install --no-dependencies --quiet validators
# !pip install --quiet openai-whisper
# !pip install --quiet librosa
# !pip install --quiet transformers huggingface_hub
# !pip install --quiet reportlab
# !pip install --quiet streamlit-audiorec
# !pip install --quiet python-dateutil
# !pip install --quiet --upgrade pymongo
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 17.8 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.8 MB/s eta 0:00:00:00:0100:01
# ...

# %%
from pyngrok import ngrok

import sys
sys.path.append("/kaggle/input/script")
import config

# Autenticazione
ngrok.set_auth_token(config.NGROK_KEY)
public_url = ngrok.connect()
print(f"Please click on the text below {public_url}")
# Out:
# Please click on the text below NgrokTunnel: "https://906d-34-83-94-235.ngrok-free.app" -> "http://localhost:80"

# %%
# !streamlit run --server.port 80 /kaggle/input/script/dashboard1.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:80
#   Network URL: http://172.19.2.2:80
#   External URL: http://34.83.94.235:80
#
# 2025-06-29 16:38:40.994561: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751215121.012649     503 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751215121.018506     503 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:01<00:00,  1.08it/s]
# ✅ JSON estratto e parsato:
# ✅ JSON estratto e parsato:
# ^C
#   Stopping...
